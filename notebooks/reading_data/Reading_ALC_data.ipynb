# %%
# import fiona
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import xarray as xr

from shapely.geometry import Point, MultiPoint

# %% [markdown]
# # Agricultural Land Classification
#
# Agricultural Land Classification data for England can be downloaded here https://data.gov.uk/dataset/952421ec-da63-4569-817d-4d6399df40a1/provisional-agricultural-land-classification-alc.
# Data includes England only.
#
#
# Agricultural land is classified into five grades, with grade one being best quality and grade five is poorest quality.
# In this notebook we plot the land classification within the historic county of Yorkshire. To obtain the Yorkshire county boundaries we use Boundary-Lane data from the Ordnance Survey Data Hub https://osdatahub.os.uk/downloads/open/BoundaryLine, which can be accessed for free by selecting the GeoPackage data format, and extracting the `bdline_gb.gpkg` file.
#
# We then store a low resolution pixelised version of the map using `xarray`, with the resolution in meters being set in  the next cell by the `resolution` parameter.

# %%
border_file = '../../data/land/bdline_gb.gpkg' 
alc_file = '../../data/land/NE_AgriculturalLandClassificationProvisionalEngland_FGDB/data.gdb/'
# Resolution in meters
resolution = 100

# %%
yorkshire_index = 66
counties = gpd.read_file(border_file, layer='boundary_line_historic_counties')
polygon = counties['geometry'].iloc[yorkshire_index]
counties
# Out:
#                Name Area_Description  \
# 0         Berkshire  Historic County
# 1   Buckinghamshire  Historic County
# 2     Hertfordshire  Historic County
# 3     Herefordshire  Historic County
# 4       Oxfordshire  Historic County
# ..              ...              ...
# 90     Warwickshire  Historic County
# 91           Dorset  Historic County
# 92            Devon  Historic County
# 93       Banffshire  Historic County
# 94            Nairn  Historic County
#
#                                              geometry
# 0   MULTIPOLYGON (((422004.502 199086.601, 422030....
# 1   MULTIPOLYGON (((460619.899 235588.003, 460625....
# 2   MULTIPOLYGON (((499772.602 215220.503, 499795....
# 3   MULTIPOLYGON (((335069.501 272770.499, 335082....
# 4   MULTIPOLYGON (((424473.304 224921.896, 424502....
# ..                                                ...
# 90  MULTIPOLYGON (((456472.501 274014.303, 456299....
# 91  MULTIPOLYGON (((333203.198 91375.703, 333185.9...
# 92  MULTIPOLYGON (((333223.945 91353.145, 333218.0...
# 93  MULTIPOLYGON (((349516.703 868874.397, 349519....
# 94  MULTIPOLYGON (((320000.101 871554.799, 320029....
#
# [95 rows x 3 columns]

# %%
cities = False

city_dict = {'Leeds' : [53.799722, -1.549167],
            'Sheffield' : [53.38297, -1.4659],
            'Bradford' : [53.8, -1.75],
            'Kingston upon Hull' : [53.744444, -0.3325],
            'York' : [53.958333, -1.080278],
            'Huddersfield' : [53.644811, -1.782137],
            'Middlesbrough' : [54.576397, -1.235758],}

# %%
alc = gpd.read_file(alc_file, mask = polygon)
# alc = gpd.read_file(alc_file)
alc
# Out:
#     geogext  ne_ne_admin_ne_agricultural_land_classification_provisional_engl  \
# 0      M59J                                           942.1277
# 1      M59J                                          2779.4511
# 2      M59J                                          6920.5087
# 3      M594                                          7576.3830
# 4      M594                                          1440.1870
# ..      ...                                                ...
# 180       9                                          3483.0100
# 181       4                                           270.5243
# 182       4                                           130.9334
# 183       4                                           616.6531
# 184       4                                          1809.1005
#
#             alc_grade  perimeter    shape_leng  shape_Length    shape_Area  \
# 0             Grade 3  18581.668  18581.667808  18581.667808  9.421277e+06
# 1             Grade 4  75890.818  75890.817695  75890.817694  2.779451e+07
# 2             Grade 5  77055.780  77055.780055  77055.780055  6.920509e+07
# 3             Grade 5  62770.201  62770.200960  62770.200960  7.576383e+07
# 4             Grade 4  41455.935  41455.934853  41455.934853  1.440187e+07
# ..                ...        ...           ...           ...           ...
# 180             Urban  55517.719  55517.719225  55517.719225  3.483010e+07
# 181           Grade 2  10556.533  10556.533213  10556.533213  2.705243e+06
# 182           Grade 3   7086.925   7086.924806   7086.924806  1.309334e+06
# 183  Non Agricultural  19874.127  19874.127001  19874.127001  6.166531e+06
# 184             Urban  31749.292  31749.291687  31749.291687  1.809100e+07
#
#                                               geometry
# 0    MULTIPOLYGON (((361710.000 486674.273, 362213....
# 1    MULTIPOLYGON (((366852.483 492413.885, 366687....
# 2    MULTIPOLYGON (((363656.712 488841.610, 365480....
# 3    MULTIPOLYGON (((382820.000 514160.000, 382740....
# 4    MULTIPOLYGON (((398934.944 516016.457, 399323....
# ..                                                 ...
# 180  MULTIPOLYGON (((458230.000 455260.000, 458420....
# 181  MULTIPOLYGON (((462266.342 522225.004, 461881....
# 182  MULTIPOLYGON (((465070.285 522358.049, 464636....
# 183  MULTIPOLYGON (((455655.585 528399.549, 455702....
# 184  MULTIPOLYGON (((458219.541 522695.580, 456263....
#
# [185 rows x 8 columns]

# %%
# Make sure both maps are using the same coordinate system
# counties = counties.to_crs(epsg=4326)
# alc = alc.to_crs(epsg=4326)

# %%
# Plot county boundary and crop polygons on the same axes.
# For some reason this is the only way I found to plot the boundary of a single county

from matplotlib import colors
pltcolors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cmap = colors.ListedColormap(pltcolors[:7])

ax_base = counties.iloc[yorkshire_index:yorkshire_index+1].boundary.plot(color = 'k', figsize = (14,14))
alc.plot('alc_grade', ax=ax_base, legend=True, markersize = 1, cmap=cmap)

if cities:
    for key in city_dict.keys():
        lat, lon = city_dict[key]
        plt.text(lon, lat, key, fontweight= 'bold')
        plt.plot(lon, lat, 'ko')

# %%
s = gpd.GeoSeries(alc['geometry'].buffer(0), crs='EPSG:27700')
d = {'alc_grade' : alc['alc_grade'] , 'geometry' : s.intersection(counties.iloc[66]['geometry'])}
alc_final = gpd.GeoDataFrame(d, crs="EPSG:27700")

# %%
# Plot county boundary and crop positions on the same axes.
# For some reason this is the only way I found to plot the boundary of a single county

ax_base = counties.iloc[yorkshire_index:yorkshire_index+1].boundary.plot(color = 'k', figsize = (14,14))
alc_final.plot('alc_grade', ax=ax_base, markersize = 1, legend=True, cmap=cmap)

if cities:
    for key in city_dict.keys():
        lat, lon = city_dict[key]
        plt.text(lon, lat, key, fontweight= 'bold')
        plt.plot(lon, lat, 'ko')

# %%
xmin, ymin, xmax, ymax = polygon.bounds
print(xmin, ymin, xmax, ymax)
size = np.ceil([(xmax - xmin)/resolution, (ymax - ymin)/resolution]).astype(int)

binsx = np.linspace(xmin, xmax, size[0]+1)
binsy = np.linspace(ymin, ymax, size[1]+1)

ypos = 0.5*(binsy[1:] + binsy[:-1])
xpos = 0.5*(binsx[1:] + binsx[:-1])

print(size)
# Out:
# 357386.0036 378555.099 542313.704 529856.1995
# [1850 1514]

# %%
alc_final
# Out:
#             alc_grade                                           geometry
# 0             Grade 3  POLYGON ((367144.995 491540.000, 366966.205 49...
# 1             Grade 4  MULTIPOLYGON (((366852.483 492413.885, 366687....
# 2             Grade 5  MULTIPOLYGON (((366687.420 493243.710, 366205....
# 3             Grade 5  MULTIPOLYGON (((386525.045 516937.930, 386522....
# 4             Grade 4  MULTIPOLYGON (((398934.944 516016.457, 399323....
# ..                ...                                                ...
# 180             Urban  MULTIPOLYGON (((458230.000 455260.000, 458420....
# 181           Grade 2  MULTIPOLYGON (((462266.342 522225.004, 461881....
# 182           Grade 3  POLYGON ((465070.285 522358.049, 464636.000 52...
# 183  Non Agricultural  MULTIPOLYGON (((455655.585 528399.549, 455702....
# 184             Urban  POLYGON ((458219.541 522695.580, 456263.694 52...
#
# [185 rows x 2 columns]

# %%
alc_codes = np.unique(alc_final['alc_grade'])
code_dict = dict(zip(alc_codes, np.arange(len(alc_codes))))
print(code_dict)
# Out:
# {'Grade 1': 0, 'Grade 2': 1, 'Grade 3': 2, 'Grade 4': 3, 'Grade 5': 4, 'Non Agricultural': 5, 'Urban': 6}

# %%
# Fill the grid positions and indexes
xxpos = np.tile(xpos, len(ypos))
ix = np.tile(np.arange(size[0]), size[1])
yypos = np.repeat(ypos, len(xpos))
iy = np.repeat(np.arange(size[1]), size[0])

# %%
df = pd.DataFrame({'xpos':ix, 'ypos':iy})
df['geometry'] = list(zip(xxpos,yypos))
df['geometry'] = df['geometry'].apply(Point)

points = gpd.GeoDataFrame(df, crs='EPSG:27700')
points
# Out:
#          xpos  ypos                       geometry
# 0           0     0  POINT (357435.984 378605.066)
# 1           1     0  POINT (357535.945 378605.066)
# 2           2     0  POINT (357635.906 378605.066)
# 3           3     0  POINT (357735.867 378605.066)
# 4           4     0  POINT (357835.828 378605.066)
# ...       ...   ...                            ...
# 2800895  1845  1513  POINT (541863.880 529806.232)
# 2800896  1846  1513  POINT (541963.841 529806.232)
# 2800897  1847  1513  POINT (542063.802 529806.232)
# 2800898  1848  1513  POINT (542163.763 529806.232)
# 2800899  1849  1513  POINT (542263.724 529806.232)
#
# [2800900 rows x 3 columns]

# %%
pointInPolys = gpd.tools.sjoin(points, alc_final, op="within", how='inner')
pointInPolys['grade'] = np.array([code_dict[g] for g in pointInPolys['alc_grade']])
pointInPolys
# Out:
#          xpos  ypos                       geometry  index_right  \
# 924       924     0  POINT (449799.873 378605.066)          112
# 925       925     0  POINT (449899.834 378605.066)          112
# 930       930     0  POINT (450399.639 378605.066)          112
# 931       931     0  POINT (450499.600 378605.066)          112
# 2773      923     1  POINT (449699.912 378705.001)          112
# ...       ...   ...                            ...          ...
# 2766732   982  1495  POINT (455597.607 528007.408)          183
# 2766733   983  1495  POINT (455697.568 528007.408)          183
# 2768583   983  1496  POINT (455697.568 528107.343)          183
# 2770433   983  1497  POINT (455697.568 528207.277)          183
# 2772283   983  1498  POINT (455697.568 528307.212)          183
#
#                 alc_grade  grade
# 924               Grade 3      2
# 925               Grade 3      2
# 930               Grade 3      2
# 931               Grade 3      2
# 2773              Grade 3      2
# ...                   ...    ...
# 2766732  Non Agricultural      5
# 2766733  Non Agricultural      5
# 2768583  Non Agricultural      5
# 2770433  Non Agricultural      5
# 2772283  Non Agricultural      5
#
# [1575555 rows x 6 columns]

# %%
grades = np.ones(size)*np.nan
grades[tuple([pointInPolys['xpos'], pointInPolys['ypos']])] = pointInPolys['grade']

# %%
plt.figure(figsize=(10,10))
plt.imshow(grades.T, interpolation='none', origin='lower', cmap=cmap)

# %%
data = xr.Dataset(
    data_vars = dict(grade=(["x", "y"], grades)),
    coords = dict(x=("x", xpos), y=("y", ypos)))

data
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 1850, y: 1514)
# Coordinates:
#   * x        (x) float64 3.574e+05 3.575e+05 3.576e+05 ... 5.422e+05 5.423e+05
#   * y        (y) float64 3.786e+05 3.787e+05 3.788e+05 ... 5.297e+05 5.298e+05
# Data variables:
#     grade    (x, y) float64 nan nan nan nan nan nan ... nan nan nan nan nan nan

# %%
encoding = {"grade":{"dtype":"float32", "zlib": True, "complevel": 5}}
data.to_netcdf(f"../../agrifoodpy/land/data/ALC/ALC_{resolution}.nc", encoding=encoding)
