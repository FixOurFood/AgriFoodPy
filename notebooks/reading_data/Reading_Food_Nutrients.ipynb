# %% [markdown]
# # Reading food Nutrient data

# %%
import numpy as np
import pandas as pd
import xarray as xr

# %% [markdown]
# TO-DO: Explain sources of data and how the excel file was generated

# %%
nutrients = pd.read_excel("../../data/food/Nutrition data.xlsx", sheet_name="Match_Items_Nutrition", header=1)
nutrients
# Out:
#    FAOSTAT balance food name  FAOSTAT ID  Default quantity - from NDNS  \
# 0          Alcohol, Non-Food        2659                           NaN
# 1                Animal fats        2946                         100.0
# 2        Apples and products        2617                         100.0
# 3    Aquatic Animals, Others        2769                         100.0
# 4             Aquatic Plants        2775                         100.0
# ..                       ...         ...                           ...
# 95     Tomatoes and products        2601                         100.0
# 96         Vegetables, Other        2605                         100.0
# 97        Wheat and products        2511                         100.0
# 98                      Wine        2655                         100.0
# 99                      Yams        2535                         100.0
#
#    Units - a tidied up version of the Units given in NDNS (e.g. 'grams' -> 'Grams')  \
# 0                                                 NaN
# 1                                               Grams
# 2                                               Grams
# 3                                               Grams
# 4                                               Grams
# ..                                                ...
# 95                                              Grams
# 96                                              Grams
# 97                                              Grams
# 98                                              Grams
# 99                                              Grams
#
#     Alpha-carotene (µg)  Alcohol (g)  Beta-carotene (µg)  \
# 0                   NaN          NaN                 NaN
# 1                   0.0          0.0               581.0
# 2                   0.0          0.0                14.0
# 3                   0.0          0.0                 0.0
# 4                   0.0          0.0               515.0
# ..                  ...          ...                 ...
# 95                  0.0          0.0               333.0
# 96                  0.0          0.0                 0.0
# 97                  0.0          0.0                 0.0
# 98                  0.0         10.7                 0.0
# 99                  0.0          0.0                 0.0
#
#     Beta cryptoxanthin (µg)  Biotin (µg)  Calcium (mg)  ...  Total sugars (g)  \
# 0                       NaN          NaN           NaN  ...               NaN
# 1                       0.0          0.0          18.0  ...               0.6
# 2                       0.0          1.0           5.0  ...              11.6
# 3                       0.0          1.0          18.0  ...               0.0
# 4                       0.0          0.0         660.0  ...               0.0
# ..                      ...          ...           ...  ...               ...
# 95                     31.0          1.0           8.0  ...               3.0
# 96                      0.0          0.0          56.0  ...               4.8
# 97                      0.0          7.0          38.0  ...               1.7
# 98                      0.0          2.0           7.0  ...               0.2
# 99                      0.0          0.0          12.0  ...               0.7
#
#     Trans fatty acids (g)  Vitamin A (retinol equivalents) (µg)  \
# 0                     NaN                                   NaN
# 1                    2.75                                1153.0
# 2                    0.00                                   2.0
# 3                    0.00                                   2.0
# 4                    0.00                                  86.0
# ..                    ...                                   ...
# 95                   0.00                                  58.0
# 96                   0.00                                   0.0
# 97                   0.00                                   0.0
# 98                   0.00                                   0.0
# 99                   0.00                                   0.0
#
#     Vitamin B12 (µg)  Vitamin B6 (mg)  Vitamin C (mg)  Vitamin D (µg)  \
# 0                NaN              NaN             NaN             NaN
# 1                0.3              0.0             0.0             0.9
# 2                0.0              0.1             5.8             0.0
# 3                1.9              0.1             0.0             0.0
# 4                2.5              0.0            15.0             0.0
# ..               ...              ...             ...             ...
# 95               0.0              0.1            22.3             0.0
# 96               0.0              0.1            47.2             0.0
# 97               0.0              0.5             0.0             0.0
# 98               0.0              0.0             0.0             0.0
# 99               0.0              0.1             4.0             0.0
#
#     Vitamin E (mg)  Water (g)  Zinc (mg)
# 0              NaN        NaN        NaN
# 1              2.0       14.8        0.0
# 2              0.1       86.2        0.0
# 3              1.0       76.9        0.6
# 4              1.7       12.2        1.7
# ..             ...        ...        ...
# 95             0.5       94.6        0.1
# 96             0.1       90.1        0.2
# 97             1.0        1.8        2.9
# 98             0.0       88.6        0.1
# 99             4.0       64.4        0.4
#
# [100 rows x 61 columns]

# %%
column_names = nutrients.columns[4:]
column_names
# Out:
# Index(['Alpha-carotene (µg)', 'Alcohol (g)', 'Beta-carotene (µg)',
#        'Beta cryptoxanthin (µg)', 'Biotin (µg)', 'Calcium (mg)',
#        'Carbohydrate (g)', 'Cholesterol (mg)', 'Chloride (mg)',
#        'Cis-Monounsaturated fatty acids (g)', 'Cis-n3 fatty acids (g)',
#        'Cis-n6 fatty acids (g)', 'Copper (mg)', 'Englyst fibre (g)', 'Fat (g)',
#        'Iron (mg)', 'B9 (Folate) (µg)', 'Fructose (g)', 'Glucose (g)',
#        'Haem iron (mg)', 'Iodine (µg)', 'Potassium (mg)', 'Energy (kcal)',
#        'Energy (kJ)', 'Lactose (g)', 'Maltose (g)', 'Magnesium (mg)',
#        'Intrinsic and milk sugars (g)', 'Manganese (mg)', 'Sodium (mg)',
#        'Nitrogen conversion factor', 'Non-haem iron (mg)',
#        'B3 (Niacin equivalent) (mg)', 'Non-milk extrinsic sugars (g)',
#        'Other Sugars (g)', 'Phosphorus (mg)', 'B5 (Pantothenic acid) (mg)',
#        'Protein (g)', 'Retinol (µg)', 'B2 (Riboflavin) (mg)',
#        'Saturated fatty acids (g)', 'Selenium (µg)', 'Starch (g)',
#        'Sucrose (g)', 'B1 (Thiamin) (mg)', 'Total carotene (µg)',
#        'Total nitrogen (g)', 'Total sugars (g)', 'Trans fatty acids (g)',
#        'Vitamin A (retinol equivalents) (µg)', 'Vitamin B12 (µg)',
#        'Vitamin B6 (mg)', 'Vitamin C (mg)', 'Vitamin D (µg)', 'Vitamin E (mg)',
#        'Water (g)', 'Zinc (mg)'],
#       dtype='object')

# %%
functional_weight = nutrients["Default quantity - from NDNS"].astype(str) + " " + nutrients["Units - a tidied up version of the Units given in NDNS (e.g. 'grams' -> 'Grams')"]
functional_weight
# Out:
# 0             NaN
# 1     100.0 Grams
# 2     100.0 Grams
# 3     100.0 Grams
# 4     100.0 Grams
#          ...
# 95    100.0 Grams
# 96    100.0 Grams
# 97    100.0 Grams
# 98    100.0 Grams
# 99    100.0 Grams
# Length: 100, dtype: object

# %%
nutrient_names = []
units = []

for column in column_names:
    try:
        nutrient_names.append(column[:column.index("(", -6)-1])
        units.append(column[column.index("(", -6):])
    except ValueError:
        nutrient_names.append(column)
        units.append(" ")

# %%
item_ids = nutrients["FAOSTAT ID"]
item_names = nutrients["FAOSTAT balance food name"]

for id, name in zip(item_ids, item_names):
    print(id, name)
# Out:
# 2659 Alcohol, Non-Food
# 2946 Animal fats
# 2617 Apples and products
# 2769 Aquatic Animals, Others
# 2775 Aquatic Plants
# 2961 Aquatic Products, Other
# 2615 Bananas
# 2513 Barley and products
# 2546 Beans
# 2656 Beer
# 2658 Beverages, Alcoholic
# 2657 Beverages, Fermented
# 2731 Bovine Meat
# 2740 Butter, Ghee
# 2532 Cassava and products
# 2766 Cephalopods
# 2520 Cereals, Other
# 2614 Citrus, Other
# 2642 Cloves
# 2633 Cocoa Beans and products
# 2578 Coconut Oil
# 2560 Coconuts - Incl Copra
# 2630 Coffee and products
# 2559 Cottonseed
# 2575 Cottonseed Oil
# 2743 Cream
# 2765 Crustaceans
# 2619 Dates
# 2762 Demersal Fish
# 2949 Eggs
# 98               0.0           11.0                                 0.00  ...
# 99               0.0           40.0                                 0.04  ...
#
#     Total sugars (g)  Trans fatty acids (g)  \
# 0                NaN                    NaN
# 1                0.6                   2.75
# 2               11.6                   0.00
# 3                0.0                   0.00
# 4                0.0                   0.00
# ..               ...                    ...
# 95               3.0                   0.00
# 96               4.8                   0.00
# 97               1.7                   0.00
# 98               0.2                   0.00
# 99               0.7                   0.00
#
#     Vitamin A (retinol equivalents) (µg)  Vitamin B12 (µg)  Vitamin B6 (mg)  \
# 0                                    NaN               NaN              NaN
# 1                                 1153.0               0.3              0.0
# 2                                    2.0               0.0              0.1
# 3                                    2.0               1.9              0.1
# 4                                   86.0               2.5              0.0
# ..                                   ...               ...              ...
# 95                                  58.0               0.0              0.1
# 96                                   0.0               0.0              0.1
# 97                                   0.0               0.0              0.5
# 98                                   0.0               0.0              0.0
# 99                                   0.0               0.0              0.1
#
#     Vitamin C (mg)  Vitamin D (µg)  Vitamin E (mg)  Water (g)  Zinc (mg)
# 0              NaN             NaN             NaN        NaN        NaN
# 1              0.0             0.9             2.0       14.8        0.0
# 2              5.8             0.0             0.1       86.2        0.0
# 3              0.0             0.0             1.0       76.9        0.6
# 4             15.0             0.0             1.7       12.2        1.7
# ..             ...             ...             ...        ...        ...
# 95            22.3             0.0             0.5       94.6        0.1
# 96            47.2             0.0             0.1       90.1        0.2
# 97             0.0             0.0             1.0        1.8        2.9
# 98             0.0             0.0             0.0       88.6        0.1
# 99             4.0             0.0             4.0       64.4        0.4
#
# [100 rows x 57 columns]

# %%
data = xr.DataArray(
    data=values,
    dims=["Item", "Nutrient"],
    
    coords = dict(
        Item=("Item", item_ids),
        Name=("Item", item_names),
        Weight=("Item", functional_weight),
        Nutrient=("Nutrient", nutrient_names),
        Units=("Nutrient", units),
    )
)
data
# Out:
# <xarray.DataArray (Item: 100, Nutrient: 57)>
# array([[     nan,      nan,      nan, ...,      nan,      nan,      nan],
#        [0.00e+00, 0.00e+00, 5.81e+02, ..., 2.00e+00, 1.48e+01, 0.00e+00],
#        [0.00e+00, 0.00e+00, 1.40e+01, ..., 1.00e-01, 8.62e+01, 0.00e+00],
#        ...,
#        [0.00e+00, 0.00e+00, 0.00e+00, ..., 1.00e+00, 1.80e+00, 2.90e+00],
#        [0.00e+00, 1.07e+01, 0.00e+00, ..., 0.00e+00, 8.86e+01, 1.00e-01],
#        [0.00e+00, 0.00e+00, 0.00e+00, ..., 4.00e+00, 6.44e+01, 4.00e-01]])
# Coordinates:
#   * Item      (Item) int64 2659 2946 2617 2769 2775 ... 2601 2605 2511 2655 2535
#     Name      (Item) object 'Alcohol, Non-Food' 'Animal fats' ... 'Wine' 'Yams'
#     Weight    (Item) object nan '100.0 Grams' ... '100.0 Grams' '100.0 Grams'
#   * Nutrient  (Nutrient) <U31 'Alpha-carotene' 'Alcohol' ... 'Water' 'Zinc'
#     Units     (Nutrient) <U6 '(µg)' '(g)' '(µg)' '(µg)' ... '(mg)' '(g)' '(mg)'

# %%
data.sel(Item=2615, Nutrient="Energy")
# Out:
# <xarray.DataArray (Nutrient: 2)>
# array([ 81., 348.])
# Coordinates:
#     Item      int64 2615
#     Name      object 'Bananas'
#     Weight    object '100.0 Grams'
#   * Nutrient  (Nutrient) <U31 'Energy' 'Energy'
#     Units     (Nutrient) <U6 '(kcal)' '(kJ)'

# %%
data.to_netcdf("../../agrifoodpy/food/data/Nutrients.nc")
